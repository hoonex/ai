# %% [markdown]
# # **🌳 국가통계포털에서 제공하는 '소비자물가지수' 데이터셋 입니다.**
#
# 🌱 각 단계에 맞추어 '**김밥의 소비자 물가 지수를 예측하는 모델**'을 제작해보세요.
#
# ✔️ 소비자물가지수? 각 가정에서 구입하는 생필품과 서비스의 가격 변동을 알아보기 위해 작성하는 통계
#
# ✔️ **[파일] - [Drive에 사본 저장]**

# %% [markdown]
# # **[단계1] 데이터 수집 및 불러오기**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-eb025a3f-8699-4072-9d45-617dab6c8dbb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eb025a3f-8699-4072-9d45-617dab6c8dbb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('consumer price index.csv')
df.head()
# Out:
#   시도별    시점     총지수   농축수산물  (농산물)곡물       쌀 현미      찹쌀     보리쌀       콩  ...  \
# 0  전국  1995  51.995  38.763   51.801  52.620  -  39.280  34.434  31.434  ...
# 1  전국  1996  54.555  39.470   59.938  60.902  -  52.688  34.434  32.783  ...
# 2  전국  1997  56.977  40.985   62.546  63.603  -  60.820  36.577  29.254  ...
# 3  전국  1998  61.258  43.469   66.569  67.701  -  63.858  49.777  29.071  ...
# 4  전국  1999  61.756  46.644   71.119  72.410  -  60.100  54.308  36.555  ...
#
#       이발료     미용료  뷰티미용료  산후조리원이용료  보험서비스료  자동차보험료    금융수수료    대입전형료  시험응시료  \
# 0  68.758  48.108      -         -       -  59.636  100.812  106.852      -
# 1  76.916  51.295      -         -       -  66.003  100.812  114.430      -
# 2  78.561  54.031      -         -       -  71.402  100.812  123.443      -
# 3  82.148  56.017      -         -       -  71.402  100.812  122.652      -
# 4  82.216  54.625      -         -       -  66.991  100.812  122.696      -
#
#    장례비
# 0    -
# 1    -
# 2    -
# 3    -
# ...

# %%
df1 = df[['김', '단무지', '쌀', '당근', '달걀', '시금치', '김밥']] # 김밥에 필요한 재료들로만 다시 df1에 저장
df1.head()
# Out:
#         김     단무지       쌀      당근      달걀     시금치      김밥
# 0  39.820  48.897  52.620  32.909  40.896  26.185  44.996
# 1  39.399  52.324  60.902  37.604  40.033  33.370  46.961
# 2  39.821  53.126  63.603  37.357  42.048  36.844  48.165
# 3  46.739  54.593  67.701  39.231  50.002  38.009  51.206
# 4  47.340  58.379  72.410  35.136  46.318  36.134  50.632

# %% [markdown]
# # **[단계2] 데이터 전처리**

# %%
# !pip install koreanize-matplotlib # 한국어 사용
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 59.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# # **[단계3] 독립변수와 종속변수 설정하기**

# %% [markdown]
# # **[단계4] 데이터 쪼개기**

# %% [markdown]
# # **[단계5] 단순 선형회귀 모델 제작**

# %% [markdown]
# # **[단계6] 단순 선형회귀 모델 성능 평가**

# %% [markdown]
# # **[단계7] 다중 선형회귀 모델 제작**

# %% [markdown]
# # **[단계8] 다중 선형회귀 모델 성능 평가**

# %% [markdown]
# # **[단계9] 물가지수를 활용한 김밥 가격 예측하는 프로그램 모델 구현하기**
